# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('output.txt') as f:
    lines = f.read().splitlines()
    loss = [float(x.split()[5].replace(",","")) for x in lines if not 'complete' in x]
x = range(len(loss))

# %%
plt.plot(x, loss)
